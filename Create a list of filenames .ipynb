# %% [markdown]
# # Get the name of all image and mask files

# %% [markdown]
# ***

# %%
import os

# %% [markdown]
# ## Method 1

# %%
train_image_dir = 'data/train/images/'
train_mask_dir = 'data/train/masks/'

# %%
train_images_filenames = os.listdir(train_image_dir)

# %%
train_images_filenames
# Out:
# ['b852505678.png',
#  'd7cf3bf4e9.png',
#  '6545c6235b.png',
#  'f1774ff8e8.png',
#  'c356f76804.png',
#  '5b2282b51e.png',
#  '7eb42fe5ec.png',
#  '8fb68e99e8.png',
#  '296de39be2.png',
#  'cb36193e2f.png',
#  '23afbccfb5.png',
#  'cb4f7abe67.png',
#  '7fadb8efe8.png',
#  '33887a0ae7.png',
#  '05f09b380c.png',
#  '7d963e0f5d.png',
#  'a2a012f128.png',
#  'b194549062.png',
#  '45180088a6.png',
#  '1a7f8bd454.png',
#  '4e3ccf37ee.png',
#  '3bf70b71cd.png',
#  '2f20c083c2.png',
#  'a3bea8f266.png',
#  'df8d9625c0.png',
#  '5f397e0074.png',
#  'd7e6e1323a.png',
#  '1a0996a817.png',
#  '3d4bc58424.png',
#  '0977568b54.png',
#  'cae1a9f23f.png',
#  'b71915a0fe.png',
#  '1986fcadda.png',
#  '58ad72a266.png',
#  'e7ee2c6dce.png',
#  '62715133c5.png',
#  'ea3cdbd7cd.png',
#  'fba91bfec8.png',
#  'd289692ab8.png',
#  '75efad62c1.png',
#  '44425dc49d.png',
#  '18ac660fbb.png',
#  '05b69f83bf.png',
#  '2d64b6a8cf.png',
#  '211dca3b80.png',
#  '57293a65d5.png',
#  '276807c93b.png',
# ...

# %%
len(train_images_filenames)
# Out:
# 4000

# %%
train_masks_filenames = os.listdir(train_mask_dir)

# %%
train_masks_filenames
# Out:
# ['b852505678.png',
#  'd7cf3bf4e9.png',
#  '6545c6235b.png',
#  'f1774ff8e8.png',
#  'c356f76804.png',
#  '5b2282b51e.png',
#  '7eb42fe5ec.png',
#  '8fb68e99e8.png',
#  '296de39be2.png',
#  'cb36193e2f.png',
#  '23afbccfb5.png',
#  'cb4f7abe67.png',
#  '7fadb8efe8.png',
#  '33887a0ae7.png',
#  '05f09b380c.png',
#  '7d963e0f5d.png',
#  'a2a012f128.png',
#  'b194549062.png',
#  '45180088a6.png',
#  '1a7f8bd454.png',
#  '4e3ccf37ee.png',
#  '3bf70b71cd.png',
#  '2f20c083c2.png',
#  'a3bea8f266.png',
#  'df8d9625c0.png',
#  '5f397e0074.png',
#  'd7e6e1323a.png',
#  '1a0996a817.png',
#  '3d4bc58424.png',
#  '0977568b54.png',
#  'cae1a9f23f.png',
#  'b71915a0fe.png',
#  '1986fcadda.png',
#  '58ad72a266.png',
#  'e7ee2c6dce.png',
#  '62715133c5.png',
#  'ea3cdbd7cd.png',
#  'fba91bfec8.png',
#  'd289692ab8.png',
#  '75efad62c1.png',
#  '44425dc49d.png',
#  '18ac660fbb.png',
#  '05b69f83bf.png',
#  '2d64b6a8cf.png',
#  '211dca3b80.png',
#  '57293a65d5.png',
#  '276807c93b.png',
# ...

# %%
len(train_masks_filenames)
# Out:
# 4000

# %% [markdown]
# # Method 2

# %%
train_image_dir = 'data/train/images/'
train_mask_dir = 'data/train/masks/'

# %%
train_images_filenames = next(os.walk(train_mask_dir))[2]

# %%
train_images_filenames
# Out:
# ['b852505678.png',
#  'd7cf3bf4e9.png',
#  '6545c6235b.png',
#  'f1774ff8e8.png',
#  'c356f76804.png',
#  '5b2282b51e.png',
#  '7eb42fe5ec.png',
#  '8fb68e99e8.png',
#  '296de39be2.png',
#  'cb36193e2f.png',
#  '23afbccfb5.png',
#  'cb4f7abe67.png',
#  '7fadb8efe8.png',
#  '33887a0ae7.png',
#  '05f09b380c.png',
#  '7d963e0f5d.png',
#  'a2a012f128.png',
#  'b194549062.png',
#  '45180088a6.png',
#  '1a7f8bd454.png',
#  '4e3ccf37ee.png',
#  '3bf70b71cd.png',
#  '2f20c083c2.png',
#  'a3bea8f266.png',
#  'df8d9625c0.png',
#  '5f397e0074.png',
#  'd7e6e1323a.png',
#  '1a0996a817.png',
#  '3d4bc58424.png',
#  '0977568b54.png',
#  'cae1a9f23f.png',
#  'b71915a0fe.png',
#  '1986fcadda.png',
#  '58ad72a266.png',
#  'e7ee2c6dce.png',
#  '62715133c5.png',
#  'ea3cdbd7cd.png',
#  'fba91bfec8.png',
#  'd289692ab8.png',
#  '75efad62c1.png',
#  '44425dc49d.png',
#  '18ac660fbb.png',
#  '05b69f83bf.png',
#  '2d64b6a8cf.png',
#  '211dca3b80.png',
#  '57293a65d5.png',
#  '276807c93b.png',
# ...

# %%
len(train_images_filenames)
# Out:
# 4000

# %%
train_masks_filenames = next(os.walk(train_mask_dir))[2]

# %%
train_masks_filenames
# Out:
# ['b852505678.png',
#  'd7cf3bf4e9.png',
#  '6545c6235b.png',
#  'f1774ff8e8.png',
#  'c356f76804.png',
#  '5b2282b51e.png',
#  '7eb42fe5ec.png',
#  '8fb68e99e8.png',
#  '296de39be2.png',
#  'cb36193e2f.png',
#  '23afbccfb5.png',
#  'cb4f7abe67.png',
#  '7fadb8efe8.png',
#  '33887a0ae7.png',
#  '05f09b380c.png',
#  '7d963e0f5d.png',
#  'a2a012f128.png',
#  'b194549062.png',
#  '45180088a6.png',
#  '1a7f8bd454.png',
#  '4e3ccf37ee.png',
#  '3bf70b71cd.png',
#  '2f20c083c2.png',
#  'a3bea8f266.png',
#  'df8d9625c0.png',
#  '5f397e0074.png',
#  'd7e6e1323a.png',
#  '1a0996a817.png',
#  '3d4bc58424.png',
#  '0977568b54.png',
#  'cae1a9f23f.png',
#  'b71915a0fe.png',
#  '1986fcadda.png',
#  '58ad72a266.png',
#  'e7ee2c6dce.png',
#  '62715133c5.png',
#  'ea3cdbd7cd.png',
#  'fba91bfec8.png',
#  'd289692ab8.png',
#  '75efad62c1.png',
#  '44425dc49d.png',
#  '18ac660fbb.png',
#  '05b69f83bf.png',
#  '2d64b6a8cf.png',
#  '211dca3b80.png',
#  '57293a65d5.png',
#  '276807c93b.png',
# ...

# %%
len(train_masks_filenames)
# Out:
# 4000
